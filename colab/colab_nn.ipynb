# %% [markdown]
# <a href="https://colab.research.google.com/github/thu-soccer/project/blob/master/colab/colab_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir("/content/gdrive/My Drive/thu-soccer/project/jupyter")
# !git pull
# !pip install -q git+https://github.com/tensorflow/docs
# !pip install tensorboardcolab
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Already up to date.
#   Building wheel for tensorflow-docs (setup.py) ... done
# Requirement already satisfied: tensorboardcolab in /usr/local/lib/python3.6/dist-packages (0.0.22)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.set_option('display.max_columns', 999)

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow_core.estimator import inputs
from tensorflow import feature_column
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.models import load_model


import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

from  IPython import display
from matplotlib import pyplot as plt

import numpy as np
import math

import pathlib
import shutil
import tempfile


def normalize_and_encode(dataframe):
    column_names_to_not_normalize = ['result']
    column_names_to_normalize = [x for x in list(dataframe) if x not in column_names_to_not_normalize ]
    x = dataframe[column_names_to_normalize].values
    x_scaled = preprocessing.normalize(x)
    df_temp = pd.DataFrame(x_scaled, columns=column_names_to_normalize, index = dataframe.index)
    dataframe[column_names_to_normalize] = df_temp

    le = preprocessing.LabelEncoder()
    le.fit([ "H", "A", "D"])
    dataframe.loc[:,['result']]=le.transform(dataframe['result'])
    
    return dataframe

def get_X_and_y(dataframe):
    X = dataframe.drop(columns=['result']).values
    y = dataframe[['result']].values
    return X,y

df01 = pd.read_csv('../data/sliding01.csv', sep=',', index_col=0)
df02 = pd.read_csv('../data/sliding02_shots.csv', sep=',', index_col=0)
df03 = pd.read_csv('../data/sliding03_shots_extra.csv', sep=',', index_col=0)
df04 = pd.read_csv('../data/sliding04_shots_and_possession.csv', sep=',', index_col=0)
df05 = pd.read_csv('../data/sliding05_shots_and_possession_extra.csv', sep=',', index_col=0)

n01 = normalize_and_encode(df01)
n02 = normalize_and_encode(df02)
n03 = normalize_and_encode(df03)
n04 = normalize_and_encode(df04)
n05 = normalize_and_encode(df05)

train01, test01 = train_test_split(n01, test_size=0.05)
print(len(train01), 'train examples')
print(len(test01), 'test examples')

train02, test02 = train_test_split(n02, test_size=0.05)
print(len(train02), 'train examples')
print(len(test02), 'test examples')

train03, test03 = train_test_split(n03, test_size=0.05)
print(len(train03), 'train examples')
print(len(test03), 'test examples')

train04, test04 = train_test_split(n04, test_size=0.05)
print(len(train04), 'train examples')
print(len(test04), 'test examples')

train05, test05 = train_test_split(n05, test_size=0.05)
print(len(train04), 'train examples')
print(len(test04), 'test examples')

train_X01,train_y01 = get_X_and_y(train01)
train_X02,train_y02 = get_X_and_y(train02)
train_X03,train_y03 = get_X_and_y(train03)
train_X04,train_y04 = get_X_and_y(train04)
train_X05,train_y05 = get_X_and_y(train05)

test_X01,test_y01 = get_X_and_y(test01)
test_X02,test_y02 = get_X_and_y(test02)
test_X03,test_y03 = get_X_and_y(test03)
test_X04,test_y04 = get_X_and_y(test04)
test_X05,test_y05 = get_X_and_y(test05)


#Many models train better if you gradually reduce the learning rate during training. Use optimizers.schedules to reduce the learning rate over time:
#The code sets a schedules.InverseTimeDecay to hyperbolically decrease the learning rate to 1/2 of the base rate at 1000 epochs, 1/3 at 2000 epochs and so on.

def get_lr_schedule(train, batch_size):
    lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    0.001,
    decay_steps=(len(train)//batch_size)*1000,
    decay_rate=1,
    staircase=False)
    return lr_schedule

def get_optimizer(train, batch_size):
    return tf.keras.optimizers.Adam(get_lr_schedule(train, batch_size))


#Each model in this tutorial will use the same training configuration. So set these up in a reusable way, starting with the list of callbacks.
#The training for this tutorial runs for many short epochs. To reduce the logging noise use the tfdocs.EpochDots which simply a . for each epoch and, and a full set of metrics every 100 epochs.

def get_callbacks(name):
    return [
        tfdocs.modeling.EpochDots(),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=200),
        #tf.keras.callbacks.TensorBoard(logdir/name), # Jupyter Notebook
        #tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1) # Google Colab
      ]

def compile_and_fit(model, name, X, y, validation_split, batch_size, optimizer=None, max_epochs=1000):
    if optimizer is None:
        optimizer = get_optimizer(X, batch_size)
    model.compile(optimizer=optimizer,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

    model.summary()
     
    history = model.fit(
        X,
        y,
        validation_split=validation_split,
        batch_size=batch_size,
#        steps_per_epoch = 50, # (len(train_X01)//batch_size,
        epochs=max_epochs,
        callbacks=get_callbacks(name),
        verbose=0)
    
    model.save("../model/%s.h5" %name) 
    
    return history

def plot_history(model_history):
	plt.plot(model_history.history['accuracy'])
	plt.plot(model_history.history['val_accuracy'])
	plt.title("%s accuracy" %model_history)
	plt.ylabel('accuracy')
	plt.xlabel('epoch')
	plt.legend(['train', 'val'], loc='upper left')
	plt.show()
	
	plt.plot(model_history.history['loss'])
	plt.plot(model_history.history['val_loss'])
	plt.title("%s loss" %model_history)
	plt.ylabel('loss')
	plt.xlabel('epoch')
	plt.legend(['train', 'val'], loc='upper left')
	plt.show()
# Out:
# 19781 train examples
# 1042 test examples
# 6681 train examples
# 352 test examples
# 6681 train examples
# 352 test examples
# 6646 train examples
# 350 test examples
# 6646 train examples
# 350 test examples

# %%
n01
# Out:
#        result  odds-home  odds-draw  odds-away  home-wins  home-draws  \
# 0           2   0.049957   0.165301   0.330601   0.183667    0.110200
# 1           1   0.077897   0.103862   0.121172   0.103862    0.138483
# 2           1   0.109311   0.117119   0.105407   0.195198    0.078079
# 3           0   0.068789   0.117049   0.155945   0.180075    0.108045
# 4           2   0.108097   0.154424   0.205899   0.102949    0.205899
# ...       ...        ...        ...        ...        ...         ...
# 20818       2   0.162536   0.123527   0.055262   0.097521    0.065014
# 20819       2   0.061498   0.110696   0.113771   0.092247    0.092247
# 20820       2   0.073697   0.153535   0.184242   0.122828    0.163770
# 20821       2   0.044350   0.175065   0.300111   0.066691    0.100037
# 20822       2   0.055791   0.140313   0.175391   0.200447    0.033408
#
#        home-losses  home-goals  home-opposition-goals  away-wins  away-draws  \
# 0         0.073467    0.514268               0.367334   0.073467    0.073467
# 1         0.103862    0.553931               0.415448   0.138483    0.103862
# 2         0.117119    0.390396               0.312317   0.156158    0.156158
# 3         0.072030    0.648271               0.396166   0.108045    0.108045
# 4         0.205899    0.308848               0.463272   0.051475    0.308848
# ...            ...         ...                    ...        ...         ...
# 20818     0.162536    0.260057               0.487607   0.065014    0.130029
# 20819     0.122995    0.307489               0.584228   0.030749    0.122995
# 20820     0.122828    0.409426               0.368484   0.204713    0.081885
shutil.rmtree(logdir, ignore_errors=True)


BATCH_SIZE = 128*8
EPOCHS=10000
validation_split = 0.2
size_histories = {}

model01 = tf.keras.Sequential([
  layers.Dense(13, activation='relu',input_shape=(train_X01.shape[1],)), # 13 features
  layers.Dense(16, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model02 = tf.keras.Sequential([
  layers.Dense(21, activation='relu',input_shape=(train_X02.shape[1],)), # 21 features
  layers.Dense(64, activation='relu'),
  layers.Dense(32, activation='relu'),
  layers.Dense(16, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model03 = tf.keras.Sequential([
  layers.Dense(29, activation='relu',input_shape=(train_X03.shape[1],)), # 29 features
  layers.Dense(64, activation='relu'),
  layers.Dense(32, activation='relu'),
  layers.Dense(16, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model04 = tf.keras.Sequential([
  layers.Dense(25, activation='relu',input_shape=(train_X04.shape[1],)), # 25 features
  layers.Dense(64, activation='relu'),
  layers.Dense(32, activation='relu'),
  layers.Dense(16, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

model05 = tf.keras.Sequential([
  layers.Dense(33, activation='relu',input_shape=(train_X05.shape[1],)), # 33 features
  layers.Dense(64, activation='relu'),
  layers.Dense(32, activation='relu'),
  layers.Dense(16, activation='relu'),
  layers.Dense(8, activation='relu'),
  layers.Dense(3, activation='softmax')
])

size_histories['model01'] = compile_and_fit(model01, 'model01', train_X01, train_y01, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model02'] = compile_and_fit(model02, 'model02', train_X02, train_y02, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model03'] = compile_and_fit(model03, 'model03', train_X03, train_y03, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model04'] = compile_and_fit(model04, 'model04', train_X04, train_y04, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
size_histories['model05'] = compile_and_fit(model05, 'model05', train_X05, train_y05, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 13)                182
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                224
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 569
# Trainable params: 569
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4599,  loss:1.0672,  val_accuracy:0.4599,  val_loss:1.0569,
# ....................................................................................................
# Epoch: 100, accuracy:0.5315,  loss:0.9714,  val_accuracy:0.5310,  val_loss:0.9694,
# ....................................................................................................
# Epoch: 200, accuracy:0.5332,  loss:0.9697,  val_accuracy:0.5325,  val_loss:0.9689,
# ....................................................................................................
# Epoch: 300, accuracy:0.5318,  loss:0.9694,  val_accuracy:0.5317,  val_loss:0.9699,
# ....................................................................................................
# Epoch: 400, accuracy:0.5334,  loss:0.9678,  val_accuracy:0.5320,  val_loss:0.9692,
# .......Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 21)                462
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                1408
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 4,641
# Trainable params: 4,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.2932,  loss:1.1015,  val_accuracy:0.2782,  val_loss:1.0989,
# ....................................................................................................
# Epoch: 100, accuracy:0.5316,  loss:0.9752,  val_accuracy:0.5370,  val_loss:0.9747,
# ....................................................................................................
# Epoch: 200, accuracy:0.5397,  loss:0.9680,  val_accuracy:0.5325,  val_loss:0.9738,
# ....................................................................................................
# Epoch: 300, accuracy:0.5365,  loss:0.9664,  val_accuracy:0.5378,  val_loss:0.9713,
# ....................................................................................................
# Epoch: 400, accuracy:0.5412,  loss:0.9619,  val_accuracy:0.5393,  val_loss:0.9698,
# ....................................................................................................
# Epoch: 500, accuracy:0.5415,  loss:0.9610,  val_accuracy:0.5378,  val_loss:0.9716,
# ....................................................................................................
# Epoch: 600, accuracy:0.5412,  loss:0.9623,  val_accuracy:0.5288,  val_loss:0.9736,
# ....................................................................................................
# Epoch: 700, accuracy:0.5432,  loss:0.9586,  val_accuracy:0.5318,  val_loss:0.9712,
# .....................Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 29)                870
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                1920
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,561
# Trainable params: 5,561
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4742,  loss:1.0944,  val_accuracy:0.4966,  val_loss:1.0917,
# ....................................................................................................
# Epoch: 100, accuracy:0.5301,  loss:0.9749,  val_accuracy:0.5370,  val_loss:0.9733,
# ....................................................................................................
# Epoch: 200, accuracy:0.5341,  loss:0.9665,  val_accuracy:0.5430,  val_loss:0.9690,
# ....................................................................................................
# Epoch: 300, accuracy:0.5309,  loss:0.9670,  val_accuracy:0.5348,  val_loss:0.9708,
# ....................................................................................................
# Epoch: 400, accuracy:0.5371,  loss:0.9589,  val_accuracy:0.5355,  val_loss:0.9697,
# ....................................................................................................
# Epoch: 500, accuracy:0.5389,  loss:0.9569,  val_accuracy:0.5430,  val_loss:0.9703,
# .......Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 25)                650
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                1664
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_20 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,085
# Trainable params: 5,085
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4597,  loss:1.0873,  val_accuracy:0.4654,  val_loss:1.0781,
# ....................................................................................................
# Epoch: 100, accuracy:0.5248,  loss:0.9841,  val_accuracy:0.5256,  val_loss:0.9865,
# ....................................................................................................
# Epoch: 200, accuracy:0.5312,  loss:0.9753,  val_accuracy:0.5338,  val_loss:0.9767,
# ....................................................................................................
# Epoch: 300, accuracy:0.5344,  loss:0.9693,  val_accuracy:0.5361,  val_loss:0.9722,
# ....................................................................................................
# Epoch: 400, accuracy:0.5314,  loss:0.9682,  val_accuracy:0.5331,  val_loss:0.9729,
# ....................................................................................................
# Epoch: 500, accuracy:0.5318,  loss:0.9679,  val_accuracy:0.5361,  val_loss:0.9706,
# ....................................................................................................
# Epoch: 600, accuracy:0.5325,  loss:0.9668,  val_accuracy:0.5406,  val_loss:0.9679,
# ....................................................................................................
# Epoch: 700, accuracy:0.5384,  loss:0.9618,  val_accuracy:0.5376,  val_loss:0.9671,
# ....................................................................................................
# Epoch: 800, accuracy:0.5403,  loss:0.9606,  val_accuracy:0.5406,  val_loss:0.9689,
# ....................................................................................................
# Epoch: 900, accuracy:0.5386,  loss:0.9609,  val_accuracy:0.5361,  val_loss:0.9667,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5382,  loss:0.9606,  val_accuracy:0.5406,  val_loss:0.9666,
# ....................................................................................................
# Epoch: 1100, accuracy:0.5436,  loss:0.9597,  val_accuracy:0.5353,  val_loss:0.9667,
# ....................................................................................................
# Epoch: 1200, accuracy:0.5414,  loss:0.9625,  val_accuracy:0.5376,  val_loss:0.9680,
# ....................................................................................................
# Epoch: 1300, accuracy:0.5444,  loss:0.9568,  val_accuracy:0.5331,  val_loss:0.9655,
# ....................................................................................................
# Epoch: 1400, accuracy:0.5436,  loss:0.9568,  val_accuracy:0.5361,  val_loss:0.9659,
# ....................................................................................................
# Epoch: 1500, accuracy:0.5427,  loss:0.9566,  val_accuracy:0.5436,  val_loss:0.9672,
# ....................................................................................................
# Epoch: 1600, accuracy:0.5435,  loss:0.9560,  val_accuracy:0.5421,  val_loss:0.9674,
# ......................................................................Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 33)                1122
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                2176
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_26 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_27 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 6,069
# Trainable params: 6,069
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4588,  loss:1.0883,  val_accuracy:0.4729,  val_loss:1.0751,
# ....................................................................................................
# Epoch: 100, accuracy:0.5233,  loss:0.9829,  val_accuracy:0.5226,  val_loss:0.9958,
# ....................................................................................................
# Epoch: 200, accuracy:0.5301,  loss:0.9752,  val_accuracy:0.5361,  val_loss:0.9780,
# ....................................................................................................
# Epoch: 300, accuracy:0.5342,  loss:0.9692,  val_accuracy:0.5338,  val_loss:0.9752,
# ....................................................................................................
# Epoch: 400, accuracy:0.5350,  loss:0.9664,  val_accuracy:0.5376,  val_loss:0.9725,
# ....................................................................................................
# Epoch: 500, accuracy:0.5378,  loss:0.9657,  val_accuracy:0.5323,  val_loss:0.9791,
# ....................................................................................................
# Epoch: 600, accuracy:0.5397,  loss:0.9635,  val_accuracy:0.5233,  val_loss:0.9864,
# ....................................................................................................
# Epoch: 700, accuracy:0.5369,  loss:0.9611,  val_accuracy:0.5301,  val_loss:0.9728,
# ....................................................................................................
# Epoch: 800, accuracy:0.5399,  loss:0.9595,  val_accuracy:0.5391,  val_loss:0.9704,
# ....................................................................................................
# Epoch: 900, accuracy:0.5440,  loss:0.9573,  val_accuracy:0.5353,  val_loss:0.9699,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5414,  loss:0.9566,  val_accuracy:0.5451,  val_loss:0.9693,
# ....................................................................................................
# Epoch: 1100, accuracy:0.5433,  loss:0.9557,  val_accuracy:0.5368,  val_loss:0.9676,
# ....................................................................................................
# Epoch: 1200, accuracy:0.5442,  loss:0.9548,  val_accuracy:0.5406,  val_loss:0.9683,
# ....................................................................................................
# Epoch: 1300, accuracy:0.5470,  loss:0.9539,  val_accuracy:0.5383,  val_loss:0.9703,
# .....................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=10)
plotter.plot(size_histories)

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
plot_history(size_histories['model01'])
plot_history(size_histories['model02'])
plot_history(size_histories['model03'])
plot_history(size_histories['model04'])
plot_history(size_histories['model05'])

# %%
score = load_model('../model/model01.h5').evaluate(test_X01, test_y01, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/model02.h5').evaluate(test_X02, test_y02, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/model03.h5').evaluate(test_X03, test_y03, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/model04.h5').evaluate(test_X04, test_y04, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/model05.h5').evaluate(test_X05, test_y05, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")
# Out:
# Test Score: 0.9910424304786433
# Test Accuracy: 0.5220729
# #####
# Test Score: 0.9809386405077848
# Test Accuracy: 0.5198864
# #####
# Test Score: 0.9888932704925537
# Test Accuracy: 0.4943182
# #####
# Test Score: 1.0056085586547852
# Test Accuracy: 0.5057143
# #####
# Test Score: 0.9962422241483416
# Test Accuracy: 0.5
# #####

# %% [markdown]
# This is apparent if you plot and compare the validation metrics to the training metrics.
#
# It's normal for there to be a small difference.
# If both metrics are moving in the same direction, everything is fine.
# If the validation metric begins to stagnate while the training metric continues to improve, you are probably close to overfitting.
# If the validation metric is going in the wrong direction, the model is clearly overfitting.

# %%
# add Add weight regularization: L2

l2_model01 = tf.keras.Sequential([
  layers.Dense(13, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X01.shape[1],)), # 13 features
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(3, activation='softmax')
])


l2_model02 = tf.keras.Sequential([
  layers.Dense(21, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X02.shape[1],)), # 21 features
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(3, activation='softmax')
])

l2_model03 = tf.keras.Sequential([
  layers.Dense(29, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X03.shape[1],)), # 29 features
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(3, activation='softmax')
])

l2_model04 = tf.keras.Sequential([
  layers.Dense(25, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X04.shape[1],)), # 25 features
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(3, activation='softmax')
])

l2_model05 = tf.keras.Sequential([
  layers.Dense(33, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X05.shape[1],)), # 33 features
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dense(3, activation='softmax')
])

l2_histories = {}

l2_histories['l2_model01'] = compile_and_fit(model01, 'l2_model01', train_X01, train_y01, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_histories['l2_model02'] = compile_and_fit(model02, 'l2_model02', train_X02, train_y02, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_histories['l2_model03'] = compile_and_fit(model03, 'l2_model03', train_X03, train_y03, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_histories['l2_model04'] = compile_and_fit(model04, 'l2_model04', train_X04, train_y04, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_histories['l2_model05'] = compile_and_fit(model05, 'l2_model05', train_X05, train_y05, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 13)                182
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                224
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 569
# Trainable params: 569
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5327,  loss:0.9690,  val_accuracy:0.5332,  val_loss:0.9706,
# ....................................................................................................
# Epoch: 100, accuracy:0.5344,  loss:0.9675,  val_accuracy:0.5342,  val_loss:0.9691,
# ....................................................................................................
# Epoch: 200, accuracy:0.5339,  loss:0.9670,  val_accuracy:0.5327,  val_loss:0.9692,
# .................Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 21)                462
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                1408
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 4,641
# Trainable params: 4,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5316,  loss:0.9709,  val_accuracy:0.5318,  val_loss:0.9712,
# ....................................................................................................
# Epoch: 100, accuracy:0.5443,  loss:0.9568,  val_accuracy:0.5363,  val_loss:0.9714,
# ....................................................................................................
# Epoch: 200, accuracy:0.5440,  loss:0.9551,  val_accuracy:0.5295,  val_loss:0.9717,
# ...............................................................Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 29)                870
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                1920
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,561
# Trainable params: 5,561
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5341,  loss:0.9657,  val_accuracy:0.5430,  val_loss:0.9736,
# ....................................................................................................
# Epoch: 100, accuracy:0.5408,  loss:0.9543,  val_accuracy:0.5385,  val_loss:0.9716,
# ....................................................................................................
# Epoch: 200, accuracy:0.5468,  loss:0.9517,  val_accuracy:0.5355,  val_loss:0.9735,
# ..............................Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 25)                650
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                1664
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_20 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,085
# Trainable params: 5,085
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5171,  loss:0.9850,  val_accuracy:0.5233,  val_loss:0.9931,
# ....................................................................................................
# Epoch: 100, accuracy:0.5418,  loss:0.9553,  val_accuracy:0.5436,  val_loss:0.9683,
# ....................................................................................................
# Epoch: 200, accuracy:0.5404,  loss:0.9545,  val_accuracy:0.5436,  val_loss:0.9689,
# .....................Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 33)                1122
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                2176
# _________________________________________________________________
# dense_24 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_25 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_26 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_27 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 6,069
# Trainable params: 6,069
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5309,  loss:0.9736,  val_accuracy:0.5361,  val_loss:0.9749,
# ....................................................................................................
# Epoch: 100, accuracy:0.5414,  loss:0.9547,  val_accuracy:0.5406,  val_loss:0.9713,
# ....................................................................................................
# Epoch: 200, accuracy:0.5467,  loss:0.9517,  val_accuracy:0.5421,  val_loss:0.9712,
# ......................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=10)
plotter.plot(l2_histories)

# %%
plotter.plot(l2_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
plot_history(l2_histories['l2_model01'])
plot_history(l2_histories['l2_model02'])
plot_history(l2_histories['l2_model03'])
plot_history(l2_histories['l2_model04'])
plot_history(l2_histories['l2_model05'])

# %%
score = load_model('../model/l2_model01.h5').evaluate(test_X01, test_y01, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_model02.h5').evaluate(test_X02, test_y02, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_model03.h5').evaluate(test_X03, test_y03, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_model04.h5').evaluate(test_X04, test_y04, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_model05.h5').evaluate(test_X05, test_y05, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")
# Out:
# Test Score: 0.993134913998236
# Test Accuracy: 0.5191939
# #####
# Test Score: 0.9847370386123657
# Test Accuracy: 0.52272725
# #####
# Test Score: 0.9917419769547202
# Test Accuracy: 0.4971591
# #####
# Test Score: 1.0080778755460467
# Test Accuracy: 0.5114286
# #####
# Test Score: 0.9970128222874233
# Test Accuracy: 0.49714285
# #####

# %%
#Add dropout

drop_model01 = tf.keras.Sequential([
  layers.Dense(13, activation='relu',input_shape=(train_X01.shape[1],)), # 13 features
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])


drop_model02 = tf.keras.Sequential([
  layers.Dense(21, activation='relu',input_shape=(train_X02.shape[1],)), # 21 features
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

drop_model03 = tf.keras.Sequential([
  layers.Dense(29, activation='relu',input_shape=(train_X03.shape[1],)), # 29 features
  layers.Dropout(0.2), 
  layers.Dense(64, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

drop_model04 = tf.keras.Sequential([
  layers.Dense(25, activation='relu',input_shape=(train_X04.shape[1],)), # 25 features
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

drop_model05 = tf.keras.Sequential([
  layers.Dense(33, activation='relu',input_shape=(train_X05.shape[1],)), # 33 features
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu'),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

drop_histories = {}

drop_histories['drop_model01'] = compile_and_fit(drop_model01, 'drop_model01', train_X01, train_y01, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
drop_histories['drop_model02'] = compile_and_fit(drop_model02, 'drop_model02', train_X02, train_y02, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
drop_histories['drop_model03'] = compile_and_fit(drop_model03, 'drop_model03', train_X03, train_y03, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
drop_histories['drop_model04'] = compile_and_fit(drop_model04, 'drop_model04', train_X04, train_y04, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
drop_histories['drop_model05'] = compile_and_fit(drop_model05, 'drop_model05', train_X05, train_y05, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_56 (Dense)             (None, 13)                182
# _________________________________________________________________
# dropout (Dropout)            (None, 13)                0
# _________________________________________________________________
# dense_57 (Dense)             (None, 16)                224
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_58 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_59 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 569
# Trainable params: 569
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4413,  loss:1.0823,  val_accuracy:0.4599,  val_loss:1.0720,
# ....................................................................................................
# Epoch: 100, accuracy:0.5294,  loss:0.9836,  val_accuracy:0.5345,  val_loss:0.9711,
# ....................................................................................................
# Epoch: 200, accuracy:0.5306,  loss:0.9821,  val_accuracy:0.5350,  val_loss:0.9713,
# ....................................................................................................
# Epoch: 300, accuracy:0.5306,  loss:0.9799,  val_accuracy:0.5380,  val_loss:0.9699,
# ....................................................................................................
# Epoch: 400, accuracy:0.5342,  loss:0.9784,  val_accuracy:0.5363,  val_loss:0.9704,
# ....................................................................................Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_60 (Dense)             (None, 21)                462
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 21)                0
# _________________________________________________________________
# dense_61 (Dense)             (None, 64)                1408
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_62 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_63 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_64 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_65 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 4,641
# Trainable params: 4,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4096,  loss:1.0874,  val_accuracy:0.4705,  val_loss:1.0767,
# ....................................................................................................
# Epoch: 100, accuracy:0.5219,  loss:0.9926,  val_accuracy:0.5318,  val_loss:0.9832,
# ....................................................................................................
# Epoch: 200, accuracy:0.5273,  loss:0.9877,  val_accuracy:0.5318,  val_loss:0.9794,
# ....................................................................................................
# Epoch: 300, accuracy:0.5292,  loss:0.9821,  val_accuracy:0.5273,  val_loss:0.9811,
# ....................................................................................................
# Epoch: 400, accuracy:0.5311,  loss:0.9756,  val_accuracy:0.5288,  val_loss:0.9767,
# ....................................................................................................
# Epoch: 500, accuracy:0.5359,  loss:0.9741,  val_accuracy:0.5325,  val_loss:0.9748,
# ....................................................................................................
# Epoch: 600, accuracy:0.5344,  loss:0.9753,  val_accuracy:0.5333,  val_loss:0.9774,
# ....................................................................................................
# Epoch: 700, accuracy:0.5359,  loss:0.9742,  val_accuracy:0.5318,  val_loss:0.9756,
# ....................................................................................................
# Epoch: 800, accuracy:0.5376,  loss:0.9716,  val_accuracy:0.5415,  val_loss:0.9724,
# ....................................................................................................
# Epoch: 900, accuracy:0.5369,  loss:0.9680,  val_accuracy:0.5438,  val_loss:0.9739,
# ...........................................................Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 29)                870
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 29)                0
# _________________________________________________________________
# dense_67 (Dense)             (None, 64)                1920
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_69 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_70 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_71 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,561
# Trainable params: 5,561
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.2914,  loss:1.1078,  val_accuracy:0.2386,  val_loss:1.0912,
# ....................................................................................................
# Epoch: 100, accuracy:0.5092,  loss:0.9940,  val_accuracy:0.5430,  val_loss:0.9771,
# ....................................................................................................
# Epoch: 200, accuracy:0.5273,  loss:0.9813,  val_accuracy:0.5445,  val_loss:0.9733,
# ....................................................................................................
# Epoch: 300, accuracy:0.5354,  loss:0.9759,  val_accuracy:0.5475,  val_loss:0.9707,
# ....................................................................................................
# Epoch: 400, accuracy:0.5369,  loss:0.9678,  val_accuracy:0.5415,  val_loss:0.9700,
# ....................................................................................................
# Epoch: 500, accuracy:0.5326,  loss:0.9683,  val_accuracy:0.5445,  val_loss:0.9723,
# ...............................................................Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (None, 25)                650
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_73 (Dense)             (None, 64)                1664
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_74 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_75 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_76 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_77 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,085
# Trainable params: 5,085
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.3723,  loss:1.0924,  val_accuracy:0.4654,  val_loss:1.0806,
# ....................................................................................................
# Epoch: 100, accuracy:0.5120,  loss:0.9992,  val_accuracy:0.5293,  val_loss:0.9879,
# ....................................................................................................
# Epoch: 200, accuracy:0.5214,  loss:0.9926,  val_accuracy:0.5293,  val_loss:0.9819,
# ....................................................................................................
# Epoch: 300, accuracy:0.5228,  loss:0.9879,  val_accuracy:0.5308,  val_loss:0.9775,
# ....................................................................................................
# Epoch: 400, accuracy:0.5245,  loss:0.9818,  val_accuracy:0.5271,  val_loss:0.9751,
# ....................................................................................................
# Epoch: 500, accuracy:0.5280,  loss:0.9831,  val_accuracy:0.5323,  val_loss:0.9743,
# ....................................................................................................
# Epoch: 600, accuracy:0.5303,  loss:0.9759,  val_accuracy:0.5278,  val_loss:0.9727,
# ....................................................................................................
# Epoch: 700, accuracy:0.5292,  loss:0.9765,  val_accuracy:0.5383,  val_loss:0.9718,
# ....................................................................................................
# Epoch: 800, accuracy:0.5275,  loss:0.9775,  val_accuracy:0.5308,  val_loss:0.9713,
# ....................................................................................................
# Epoch: 900, accuracy:0.5316,  loss:0.9751,  val_accuracy:0.5346,  val_loss:0.9703,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5295,  loss:0.9756,  val_accuracy:0.5346,  val_loss:0.9689,
# .......................................Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_78 (Dense)             (None, 33)                1122
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 33)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 64)                2176
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_81 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_82 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_83 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 6,069
# Trainable params: 6,069
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4253,  loss:1.0845,  val_accuracy:0.4729,  val_loss:1.0700,
# ....................................................................................................
# Epoch: 100, accuracy:0.5162,  loss:0.9990,  val_accuracy:0.5263,  val_loss:0.9847,
# ....................................................................................................
# Epoch: 200, accuracy:0.5305,  loss:0.9877,  val_accuracy:0.5331,  val_loss:0.9790,
# ....................................................................................................
# Epoch: 300, accuracy:0.5320,  loss:0.9840,  val_accuracy:0.5308,  val_loss:0.9751,
# ....................................................................................................
# Epoch: 400, accuracy:0.5310,  loss:0.9750,  val_accuracy:0.5301,  val_loss:0.9728,
# ....................................................................................................
# Epoch: 500, accuracy:0.5340,  loss:0.9773,  val_accuracy:0.5331,  val_loss:0.9731,
# ....................................................................................................
# Epoch: 600, accuracy:0.5391,  loss:0.9702,  val_accuracy:0.5406,  val_loss:0.9732,
# ....................................................................................................
# Epoch: 700, accuracy:0.5372,  loss:0.9695,  val_accuracy:0.5346,  val_loss:0.9743,
# .......................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=10)
plotter.plot(drop_histories)

# %%
plotter.plot(drop_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
plot_history(drop_histories['drop_model01'])
plot_history(drop_histories['drop_model02'])
plot_history(drop_histories['drop_model03'])
plot_history(drop_histories['drop_model04'])
plot_history(drop_histories['drop_model05'])

# %%
score = load_model('../model/drop_model01.h5').evaluate(test_X01, test_y01, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/drop_model02.h5').evaluate(test_X02, test_y02, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/drop_model03.h5').evaluate(test_X03, test_y03, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/drop_model04.h5').evaluate(test_X04, test_y04, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/drop_model05.h5').evaluate(test_X05, test_y05, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")
# Out:
# Test Score: 0.988166030103094
# Test Accuracy: 0.5191939
# #####
# Test Score: 0.9810995134440336
# Test Accuracy: 0.5369318
# #####
# Test Score: 0.9888494990088723
# Test Accuracy: 0.5113636
# #####
# Test Score: 1.0009704044886998
# Test Accuracy: 0.49142858
# #####
# Test Score: 1.0056589310509818
# Test Accuracy: 0.4942857
# #####

# %%
# dropout and regularization

l2_drop_model01 = tf.keras.Sequential([
  layers.Dense(13, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X01.shape[1],)), # 13 features
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])


l2_drop_model02 = tf.keras.Sequential([
  layers.Dense(21, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X02.shape[1],)), # 21 features
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

l2_drop_model03 = tf.keras.Sequential([
  layers.Dense(29, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X03.shape[1],)), # 29 features
  layers.Dropout(0.2), 
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

l2_drop_model04 = tf.keras.Sequential([
  layers.Dense(25, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X04.shape[1],)), # 25 features
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

l2_drop_model05 = tf.keras.Sequential([
  layers.Dense(33, activation='relu',kernel_regularizer=regularizers.l2(0.001),input_shape=(train_X05.shape[1],)), # 33 features
  layers.Dropout(0.2),
  layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001),),
  layers.Dropout(0.2),
  layers.Dense(3, activation='softmax')
])

l2_drop_histories = {}

l2_drop_histories['l2_drop_model01'] = compile_and_fit(l2_drop_model01, 'l2_drop_model01', train_X01, train_y01, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_drop_histories['l2_drop_model02'] = compile_and_fit(l2_drop_model02, 'l2_drop_model02', train_X02, train_y02, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_drop_histories['l2_drop_model03'] = compile_and_fit(l2_drop_model03, 'l2_drop_model03', train_X03, train_y03, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_drop_histories['l2_drop_model04'] = compile_and_fit(l2_drop_model04, 'l2_drop_model04', train_X04, train_y04, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
l2_drop_histories['l2_drop_model05'] = compile_and_fit(l2_drop_model05, 'l2_drop_model05', train_X05, train_y05, validation_split=validation_split,batch_size=BATCH_SIZE,max_epochs=EPOCHS)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_84 (Dense)             (None, 13)                182
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 13)                0
# _________________________________________________________________
# dense_85 (Dense)             (None, 16)                224
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_86 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_87 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 569
# Trainable params: 569
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4380,  loss:1.1201,  val_accuracy:0.4632,  val_loss:1.1043,
# ....................................................................................................
# Epoch: 100, accuracy:0.5277,  loss:0.9954,  val_accuracy:0.5330,  val_loss:0.9839,
# ....................................................................................................
# Epoch: 200, accuracy:0.5262,  loss:0.9928,  val_accuracy:0.5335,  val_loss:0.9807,
# ....................................................................................................
# Epoch: 300, accuracy:0.5293,  loss:0.9900,  val_accuracy:0.5340,  val_loss:0.9795,
# ....................................................................................................
# Epoch: 400, accuracy:0.5302,  loss:0.9894,  val_accuracy:0.5345,  val_loss:0.9787,
# ....................................................................................................
# Epoch: 500, accuracy:0.5289,  loss:0.9887,  val_accuracy:0.5335,  val_loss:0.9780,
# ....................................................................................................
# Epoch: 600, accuracy:0.5293,  loss:0.9878,  val_accuracy:0.5342,  val_loss:0.9777,
# ....................................................................................................
# Epoch: 700, accuracy:0.5285,  loss:0.9872,  val_accuracy:0.5330,  val_loss:0.9781,
# ....................................................................................................
# Epoch: 800, accuracy:0.5260,  loss:0.9872,  val_accuracy:0.5330,  val_loss:0.9772,
# ....................................................................................................
# Epoch: 900, accuracy:0.5287,  loss:0.9860,  val_accuracy:0.5345,  val_loss:0.9765,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5300,  loss:0.9874,  val_accuracy:0.5322,  val_loss:0.9766,
# ....................................................................................................
# Epoch: 1100, accuracy:0.5294,  loss:0.9861,  val_accuracy:0.5340,  val_loss:0.9760,
# ....................................................................................................
# Epoch: 1200, accuracy:0.5314,  loss:0.9830,  val_accuracy:0.5345,  val_loss:0.9754,
# ....................................................................................................
# Epoch: 1300, accuracy:0.5286,  loss:0.9865,  val_accuracy:0.5332,  val_loss:0.9760,
# ....................................................................................................
# Epoch: 1400, accuracy:0.5303,  loss:0.9861,  val_accuracy:0.5340,  val_loss:0.9758,
# .Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 21)                462
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 21)                0
# _________________________________________________________________
# dense_89 (Dense)             (None, 64)                1408
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_90 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_91 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_93 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 4,641
# Trainable params: 4,641
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.3958,  loss:1.2163,  val_accuracy:0.4705,  val_loss:1.2039,
# ....................................................................................................
# Epoch: 100, accuracy:0.5148,  loss:1.0319,  val_accuracy:0.5280,  val_loss:1.0123,
# ....................................................................................................
# Epoch: 200, accuracy:0.5256,  loss:1.0162,  val_accuracy:0.5333,  val_loss:0.9977,
# ....................................................................................................
# Epoch: 300, accuracy:0.5277,  loss:1.0102,  val_accuracy:0.5400,  val_loss:0.9950,
# ....................................................................................................
# Epoch: 400, accuracy:0.5251,  loss:1.0119,  val_accuracy:0.5400,  val_loss:0.9945,
# ....................................................................................................
# Epoch: 500, accuracy:0.5290,  loss:1.0090,  val_accuracy:0.5415,  val_loss:0.9920,
# ....................................................................................................
# Epoch: 600, accuracy:0.5298,  loss:1.0020,  val_accuracy:0.5295,  val_loss:0.9941,
# ....................................................................................................
# Epoch: 700, accuracy:0.5309,  loss:1.0010,  val_accuracy:0.5340,  val_loss:0.9930,
# ....................................................................................................
# Epoch: 800, accuracy:0.5314,  loss:1.0040,  val_accuracy:0.5333,  val_loss:0.9922,
# ....................................................................................................
# Epoch: 900, accuracy:0.5352,  loss:1.0049,  val_accuracy:0.5348,  val_loss:0.9915,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5359,  loss:1.0014,  val_accuracy:0.5325,  val_loss:0.9922,
# .......................Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (None, 29)                870
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 29)                0
# _________________________________________________________________
# dense_95 (Dense)             (None, 64)                1920
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_96 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_97 (Dense)             (None, 16)                528
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_98 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_99 (Dense)             (None, 3)                 27
# =================================================================
# Total params: 5,561
# Trainable params: 5,561
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4296,  loss:1.2344,  val_accuracy:0.4585,  val_loss:1.2241,
# ....................................................................................................
# Epoch: 100, accuracy:0.5129,  loss:1.0247,  val_accuracy:0.5280,  val_loss:1.0098,
# ....................................................................................................
# Epoch: 200, accuracy:0.5226,  loss:1.0157,  val_accuracy:0.5408,  val_loss:0.9994,
# ....................................................................................................
# Epoch: 300, accuracy:0.5221,  loss:1.0073,  val_accuracy:0.5467,  val_loss:0.9945,
# ....................................................................................................
# Epoch: 400, accuracy:0.5249,  loss:1.0085,  val_accuracy:0.5393,  val_loss:0.9931,
# ....................................................................................................
# Epoch: 500, accuracy:0.5303,  loss:1.0090,  val_accuracy:0.5445,  val_loss:0.9920,
# ....................................................................................................
# Epoch: 600, accuracy:0.5292,  loss:1.0044,  val_accuracy:0.5460,  val_loss:0.9902,
# ....................................................................................................
# Epoch: 700, accuracy:0.5286,  loss:1.0068,  val_accuracy:0.5393,  val_loss:0.9910,
# ....................................................................................................
# Epoch: 800, accuracy:0.5344,  loss:0.9994,  val_accuracy:0.5370,  val_loss:0.9896,
# ....................................................................................................
# Epoch: 900, accuracy:0.5264,  loss:1.0018,  val_accuracy:0.5445,  val_loss:0.9903,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5322,  loss:1.0022,  val_accuracy:0.5423,  val_loss:0.9898,
# ....................................................................................................
# Epoch: 1100, accuracy:0.5301,  loss:0.9977,  val_accuracy:0.5393,  val_loss:0.9901,
# ....................................................................................................
# Epoch: 1200, accuracy:0.5361,  loss:0.9969,  val_accuracy:0.5475,  val_loss:0.9877,
# ....................................................................................................
# Epoch: 1300, accuracy:0.5344,  loss:0.9959,  val_accuracy:0.5467,  val_loss:0.9891,
# ....................................................................................................
# Epoch: 1400, accuracy:0.5316,  loss:0.9999,  val_accuracy:0.5438,  val_loss:0.9885,
# ....................................................................................................
# Epoch: 1500, accuracy:0.5316,  loss:1.0016,  val_accuracy:0.5415,  val_loss:0.9891,
# ....................................................................................................
# Epoch: 1600, accuracy:0.5348,  loss:0.9973,  val_accuracy:0.5400,  val_loss:0.9886,
# ................................Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_100 (Dense)            (None, 25)                650
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 25)                0
# _________________________________________________________________
# dense_101 (Dense)            (None, 64)                1664
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_102 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_103 (Dense)            (None, 16)                528
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 8)                 136
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_105 (Dense)            (None, 3)                 27
# =================================================================
# Total params: 5,085
# Trainable params: 5,085
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4347,  loss:1.2190,  val_accuracy:0.4654,  val_loss:1.1962,
# ....................................................................................................
# Epoch: 100, accuracy:0.5077,  loss:1.0302,  val_accuracy:0.5180,  val_loss:1.0200,
# ....................................................................................................
# Epoch: 200, accuracy:0.5122,  loss:1.0286,  val_accuracy:0.5180,  val_loss:1.0143,
# ....................................................................................................
# Epoch: 300, accuracy:0.5132,  loss:1.0235,  val_accuracy:0.5211,  val_loss:1.0119,
# ....................................................................................................
# Epoch: 400, accuracy:0.5147,  loss:1.0208,  val_accuracy:0.5211,  val_loss:1.0099,
# ....................................................................................................
# Epoch: 500, accuracy:0.5124,  loss:1.0249,  val_accuracy:0.5263,  val_loss:1.0087,
# ....................................................................................................
# Epoch: 600, accuracy:0.5182,  loss:1.0230,  val_accuracy:0.5248,  val_loss:1.0074,
# ....................................................................................................
# Epoch: 700, accuracy:0.5166,  loss:1.0215,  val_accuracy:0.5278,  val_loss:1.0071,
# ....................................................................................................
# Epoch: 800, accuracy:0.5166,  loss:1.0199,  val_accuracy:0.5256,  val_loss:1.0058,
# ....................................................................................................
# Epoch: 900, accuracy:0.5235,  loss:1.0163,  val_accuracy:0.5256,  val_loss:1.0048,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5220,  loss:1.0153,  val_accuracy:0.5301,  val_loss:1.0038,
# ....................................................................................................
# Epoch: 1100, accuracy:0.5214,  loss:1.0136,  val_accuracy:0.5278,  val_loss:1.0028,
# ....................................................................................................
# Epoch: 1200, accuracy:0.5269,  loss:1.0125,  val_accuracy:0.5301,  val_loss:1.0026,
# ....................................................................................................
# Epoch: 1300, accuracy:0.5194,  loss:1.0141,  val_accuracy:0.5301,  val_loss:1.0010,
# ....................................................................................................
# Epoch: 1400, accuracy:0.5239,  loss:1.0151,  val_accuracy:0.5256,  val_loss:1.0007,
# ....................................................................................................
# Epoch: 1500, accuracy:0.5241,  loss:1.0119,  val_accuracy:0.5316,  val_loss:0.9989,
# ....................................................................................................
# Epoch: 1600, accuracy:0.5252,  loss:1.0113,  val_accuracy:0.5323,  val_loss:0.9992,
# ....................................................................................................
# Epoch: 1700, accuracy:0.5203,  loss:1.0095,  val_accuracy:0.5338,  val_loss:0.9983,
# ....................................................................................................
# Epoch: 1800, accuracy:0.5246,  loss:1.0093,  val_accuracy:0.5278,  val_loss:0.9993,
# ....................................................................................................
# Epoch: 1900, accuracy:0.5194,  loss:1.0123,  val_accuracy:0.5233,  val_loss:0.9978,
# ....................................................................................................
# Epoch: 2000, accuracy:0.5243,  loss:1.0118,  val_accuracy:0.5248,  val_loss:0.9969,
# ....................................................................................................
# Epoch: 2100, accuracy:0.5252,  loss:1.0085,  val_accuracy:0.5278,  val_loss:0.9975,
# ....................................................................................................
# Epoch: 2200, accuracy:0.5229,  loss:1.0087,  val_accuracy:0.5293,  val_loss:0.9960,
# ....................................................................................................
# Epoch: 2300, accuracy:0.5282,  loss:1.0108,  val_accuracy:0.5256,  val_loss:0.9960,
# ....................................................................................................
# Epoch: 2400, accuracy:0.5224,  loss:1.0107,  val_accuracy:0.5278,  val_loss:0.9965,
# ....................................................................................................
# Epoch: 2500, accuracy:0.5258,  loss:1.0093,  val_accuracy:0.5346,  val_loss:0.9967,
# ....................................................................................................
# Epoch: 2600, accuracy:0.5310,  loss:1.0053,  val_accuracy:0.5286,  val_loss:0.9956,
# ....................................................................................................
# Epoch: 2700, accuracy:0.5286,  loss:1.0075,  val_accuracy:0.5316,  val_loss:0.9955,
# ....................................................................................................
# Epoch: 2800, accuracy:0.5254,  loss:1.0079,  val_accuracy:0.5316,  val_loss:0.9947,
# ....................................................................................................
# Epoch: 2900, accuracy:0.5261,  loss:1.0081,  val_accuracy:0.5293,  val_loss:0.9943,
# .............................................................................Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_106 (Dense)            (None, 33)                1122
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 33)                0
# _________________________________________________________________
# dense_107 (Dense)            (None, 64)                2176
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_108 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_109 (Dense)            (None, 16)                528
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_110 (Dense)            (None, 8)                 136
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_111 (Dense)            (None, 3)                 27
# =================================================================
# Total params: 6,069
# Trainable params: 6,069
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.2980,  loss:1.2506,  val_accuracy:0.4729,  val_loss:1.2389,
# ....................................................................................................
# Epoch: 100, accuracy:0.5134,  loss:1.0276,  val_accuracy:0.5233,  val_loss:1.0173,
# ....................................................................................................
# Epoch: 200, accuracy:0.5158,  loss:1.0253,  val_accuracy:0.5278,  val_loss:1.0125,
# ....................................................................................................
# Epoch: 300, accuracy:0.5152,  loss:1.0201,  val_accuracy:0.5241,  val_loss:1.0084,
# ....................................................................................................
# Epoch: 400, accuracy:0.5188,  loss:1.0176,  val_accuracy:0.5271,  val_loss:1.0068,
# ....................................................................................................
# Epoch: 500, accuracy:0.5160,  loss:1.0193,  val_accuracy:0.5346,  val_loss:1.0065,
# ....................................................................................................
# Epoch: 600, accuracy:0.5182,  loss:1.0216,  val_accuracy:0.5256,  val_loss:1.0064,
# ....................................................................................................
# Epoch: 700, accuracy:0.5248,  loss:1.0157,  val_accuracy:0.5323,  val_loss:1.0040,
# ....................................................................................................
# Epoch: 800, accuracy:0.5179,  loss:1.0200,  val_accuracy:0.5323,  val_loss:1.0034,
# ....................................................................................................
# Epoch: 900, accuracy:0.5184,  loss:1.0144,  val_accuracy:0.5301,  val_loss:1.0025,
# ....................................................................................................
# Epoch: 1000, accuracy:0.5273,  loss:1.0137,  val_accuracy:0.5338,  val_loss:1.0021,
# ....................................................................................................
# Epoch: 1100, accuracy:0.5154,  loss:1.0169,  val_accuracy:0.5271,  val_loss:1.0041,
# ....................................................................................................
# Epoch: 1200, accuracy:0.5241,  loss:1.0156,  val_accuracy:0.5308,  val_loss:1.0035,
# ....................................................................................................
# Epoch: 1300, accuracy:0.5162,  loss:1.0161,  val_accuracy:0.5286,  val_loss:1.0011,
# ....................................................................................................
# Epoch: 1400, accuracy:0.5224,  loss:1.0141,  val_accuracy:0.5308,  val_loss:1.0008,
# ....................................................................................................
# Epoch: 1500, accuracy:0.5269,  loss:1.0115,  val_accuracy:0.5286,  val_loss:1.0020,
# ....................................................................................................
# Epoch: 1600, accuracy:0.5286,  loss:1.0064,  val_accuracy:0.5316,  val_loss:0.9992,
# ....................................................................................................
# Epoch: 1700, accuracy:0.5256,  loss:1.0135,  val_accuracy:0.5346,  val_loss:0.9983,
# ....................................................................................................
# Epoch: 1800, accuracy:0.5207,  loss:1.0120,  val_accuracy:0.5308,  val_loss:0.9997,
# ....................................................................................................
# Epoch: 1900, accuracy:0.5282,  loss:1.0092,  val_accuracy:0.5301,  val_loss:0.9998,
# ....................................................................................................
# Epoch: 2000, accuracy:0.5248,  loss:1.0097,  val_accuracy:0.5331,  val_loss:0.9991,
# ....................................................................................................
# Epoch: 2100, accuracy:0.5273,  loss:1.0090,  val_accuracy:0.5271,  val_loss:0.9990,
# ....................................................................................................
# Epoch: 2200, accuracy:0.5229,  loss:1.0082,  val_accuracy:0.5353,  val_loss:0.9966,
# ....................................................................................................
# Epoch: 2300, accuracy:0.5254,  loss:1.0065,  val_accuracy:0.5286,  val_loss:0.9983,
# ....................................................................................................
# Epoch: 2400, accuracy:0.5263,  loss:1.0065,  val_accuracy:0.5346,  val_loss:0.9968,
# ....................................................................................................
# Epoch: 2500, accuracy:0.5288,  loss:1.0040,  val_accuracy:0.5338,  val_loss:0.9974,
# .....

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=10)
plotter.plot(l2_drop_histories)

# %%
plotter.plot(l2_drop_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
#plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
plot_history(l2_drop_histories['l2_drop_model01'])
plot_history(l2_drop_histories['l2_drop_model02'])
plot_history(l2_drop_histories['l2_drop_model03'])
plot_history(l2_drop_histories['l2_drop_model04'])
plot_history(l2_drop_histories['l2_drop_model05'])

# %%
score = load_model('../model/l2_drop_model01.h5').evaluate(test_X01, test_y01, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_drop_model02.h5').evaluate(test_X02, test_y02, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_drop_model03.h5').evaluate(test_X03, test_y03, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_drop_model04.h5').evaluate(test_X04, test_y04, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")

score = load_model('../model/l2_drop_model05.h5').evaluate(test_X05, test_y05, verbose=3)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
print("#####")
# Out:
# Test Score: 0.9902424844350101
# Test Accuracy: 0.5268714
# #####
# Test Score: 1.004785949533636
# Test Accuracy: 0.50852275
# #####
# Test Score: 1.0069468075578862
# Test Accuracy: 0.50852275
# #####
# Test Score: 1.0200295983042036
# Test Accuracy: 0.4857143
# #####
# Test Score: 1.0267811523165022
# Test Accuracy: 0.50285715
# #####
