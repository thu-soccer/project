# %%
import process_csv_data
import pandas as pd
data = process_csv_data.Dataset('../data/matches_all.csv')

# %%
df = pd.DataFrame(data.processed_results)

# %%
df
# Out:
#       result  odds-home  odds-draw  odds-away  home-wins  home-draws  \
# 0          A       1.36       4.75       8.50          7           1
# 1          D       2.40       3.30       2.90          2           3
# 2          D       3.20       3.30       2.25          4           2
# 3          H       1.75       3.75       4.33          4           1
# 4          D       1.40       4.33       8.00          5           3
# ...      ...        ...        ...        ...        ...         ...
# 23949      D       0.00       0.00       0.00          3           3
# 23950      H       0.00       0.00       0.00          3           2
# 23951      A       0.00       0.00       0.00          1           4
# 23952      H       0.00       0.00       0.00          6           2
# 23953      H       0.00       0.00       0.00          5           3
#
#        home-losses  home-goals  home-opposition-goals  away-wins  away-draws  \
# ...

# %%
df.to_csv('../data/sliding_window_result_all_matches.csv')
